# %%
import pandas as pd 
df = pd.read_csv("YearDegreeEvent", sep = "\t")

# %%
df.head()
# Out:
#    Year  Degree Event  Unnamed: 3
# 0  2023       1     ☊         NaN
# 1  2023       6     ⬆         NaN
# 2  2023       6     🌕         NaN
# 3  2023       8     𝔸         NaN
# 4  2023      16     ☋         NaN

# %%
df.iloc[1:365].plot(x='Year', y="Degree")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
import numpy as np
import matplotlib.pyplot as plt


# Fixing random state for reproducibility
np.random.seed(19680801)

# Compute areas and colors
N = 150
r = 2 * np.random.rand(N)
theta = 2 * np.pi * np.random.rand(N)
area = 200 * r**2
colors = theta

fig = plt.figure()
ax = fig.add_subplot(projection='polar')
c = ax.scatter(theta, r, c=colors, s=area, cmap='hsv', alpha=0.75)

# %%
import numpy as np
import matplotlib.pyplot as plt

r = (df.Year-2023)/19+.6
theta = df.Degree
fig = plt.figure(figsize=(40,20))
ax = fig.add_subplot(projection='polar')
c = ax.scatter(theta, r, marker="$\u25b2$")

# %%
# Plot a circle with radius 2 using polar form
rads = np.arange(0, 360, 1)

for radian in rads:
    plot.polar(degs,2,'o')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/yg/131ptx4953j4cgjzcpkv78fw0000gn/T/ipykernel_5224/1289279027.py in <module>
#       3
#       4 for radian in rads:
# ----> 5     plot.polar(degs,2,'o')
#
# NameError: name 'degs' is not defined

# %%
asdf = (df.Year-2023)/19

# %%
df["Event"][1:20]
# Out:
# 1     ⬆
# 2     🌕
# 3     𝔸
# 4     ☋
# 5     ⬇
# 6     🌑
# 7     ℙ
# 8     ☊
# 9     ⬆
# 10    𝔸
# 11    🌕
# 12    ☋
# 13    ⬇
# 14    ℙ
# 15    🌑
# 16    ☊
# 17    ⬆
# 18    𝔸
# 19    🌕
# Name: Event, dtype: object

# %%
1     ⬆
2     🌕
3     𝔸
4     ☋
5     ⬇
6     🌑
7     ℙ
8     ☊
9     ⬆
10    𝔸
11    🌕
12    ☋
13    ⬇
14    ℙ
15    🌑
16    ☊
17    ⬆
18    𝔸
19    🌕
# Out:
#   File "/var/folders/yg/131ptx4953j4cgjzcpkv78fw0000gn/T/ipykernel_5224/877588653.py", line 1
#     df.loc[df["Event"] = 2024, "Year"]
#                        ^
# SyntaxError: invalid syntax

# %%
ascendings = df[df["Event"] == '☊']
descendings = df[df["Event"] == '☋']
perigees = df[df["Event"] == 'ℙ']
apogees = df[df["Event"] == '𝔸']
souths = df[df["Event"] == '⬇']
norths = df[df["Event"] == '⬆']
fulls = df[df["Event"] == '🌕']
news = df[df["Event"] == '🌑']
c = ax.scatter(theta, r, marker="$\u260A$")
c = ax.scatter(theta, r, marker="$\u260B$")
c = ax.scatter(theta, r, marker="$\u2119$")

c = ax.scatter(theta, r, marker="$\u25b2$")
c = ax.scatter(theta, r, marker="$\u25b2$")
c = ax.scatter(theta, r, marker="$\u25b2$")

# %%
import numpy as np
import matplotlib.pyplot as plt

r = (ascendings.Year-2023)/19+.6
theta = ascendings.Degree
fig = plt.figure(figsize=(40,20))
ax = fig.add_subplot(projection='polar')
c = ax.scatter(theta, r, marker="$\u260A$")
r2 = (descendings.Year-2023)/19+.6
theta2 = descendings.Degree
c = ax.scatter(theta2, r2, marker="$\u260B$")
r3 = (perigees.Year-2023)/19+.6
theta3 = perigees.Degree
#c = ax.scatter(theta3, r3, marker="$\u2119$")

# %%
import numpy as np
import matplotlib.pyplot as plt

r = (ascendings.Year-2023)/19+.6
theta = ascendings.Degree
fig = plt.figure(figsize=(40,20))
ax = fig.add_subplot(projection='polar')
c = ax.scatter(theta, r, marker="$\u25b2$")


r = (descendings.Year-2023)/19+.6
theta = ascendings.Degree
fig = plt.figure(figsize=(40,20))
ax = fig.add_subplot(projection='polar')
c = ax.scatter(theta, r, marker="$\u25b2$")

# %%
r = (ascendings.Year-2023)/19+.6
theta = ascendings.Degree
fig = plt.figure(figsize=(40,20))
ax = fig.add_subplot(projection='polar')
c = ax.scatter(theta, r, marker="$\u25b2$")


r = (ascendings.Year-2023)/19+.6
theta = ascendings.Degree
fig = plt.figure(figsize=(40,20))
ax = fig.add_subplot(projection='polar')
c = ax.scatter(theta, r, marker="$\u25b2$")


r = (ascendings.Year-2023)/19+.6
theta = ascendings.Degree
fig = plt.figure(figsize=(40,20))
ax = fig.add_subplot(projection='polar')
c = ax.scatter(theta, r, marker="$\u25b2$")

# %%
ascendings
# Out:
# (      Year  Degree Event  Unnamed: 3
#  0     2023       1     ☊         NaN
#  8     2023      28     ☊         NaN
#  16    2023      54     ☊         NaN
#  24    2023      82     ☊         NaN
#  32    2023     108     ☊         NaN
#  ...    ...     ...   ...         ...
#  2063  2042     241     ☊         NaN
#  2071  2042     269     ☊         NaN
#  2077  2042     296     ☊         NaN
#  2085  2042     323     ☊         NaN
#  2093  2042     350     ☊         NaN
#
#  [269 rows x 4 columns],
#        Year  Degree Event  Unnamed: 3
#  4     2023      16     ☋         NaN
#  12    2023      42     ☋         NaN
#  20    2023      69     ☋         NaN
#  28    2023      96     ☋         NaN
#  35    2023     122     ☋         NaN
#  ...    ...     ...   ...         ...
#  2058  2042     229     ☋         NaN
#  2066  2042     255     ☋         NaN
#  2073  2042     282     ☋         NaN
#  2081  2042     309     ☋         NaN
#  2089  2042     336     ☋         NaN
#
# ...

# %%
descendings
# Out:
#       Year  Degree Event  Unnamed: 3
# 4     2023      16     ☋         NaN
# 12    2023      42     ☋         NaN
# 20    2023      69     ☋         NaN
# 28    2023      96     ☋         NaN
# 35    2023     122     ☋         NaN
# ...    ...     ...   ...         ...
# 2058  2042     229     ☋         NaN
# 2066  2042     255     ☋         NaN
# 2073  2042     282     ☋         NaN
# 2081  2042     309     ☋         NaN
# 2089  2042     336     ☋         NaN
#
# [268 rows x 4 columns]

# %%
ascendings.Degree.astype(int)
# Out:
# 0         1
# 8        28
# 16       54
# 24       82
# 32      108
#        ...
# 2063    241
# 2071    269
# 2077    296
# 2085    323
# 2093    350
# Name: Degree, Length: 269, dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt

r = (ascendings.Year-2022)/19+.6
theta = ascendings.Degree
fig = plt.figure(figsize=(40,20))
ax = fig.add_subplot(projection='polar')
c = ax.scatter(theta, r, marker="$\u260A$")
r2 = (descendings.Year-2022)/19+.6
theta2 = descendings.Degree
c = ax.scatter(theta2, r2, marker="$\u260B$")

# %%
import numpy as np
import matplotlib.pyplot as plt

descendingsshorts = descendings.loc[descendings["Year"] < 2024]
ascendingsshorts = ascendings.loc[ascendings["Year"] < 2024]
r = (ascendingsshorts.Year-2022)/19+.6
theta = ascendingsshorts.Degree
fig = plt.figure(figsize=(40,20))
ax = fig.add_subplot(projection='polar')
c = ax.scatter(theta, r, marker="$\u260A$")
r2 = (descendingsshorts.Year-2022)/19+.6
theta2 = descendingsshorts.Degree
c = ax.scatter(theta2, r2, marker="$\u260B$")

# %%
descendingsshorts
# Out:
#       Year  Degree Event  Unnamed: 3
# 4     2023      16     ☋         NaN
# 12    2023      42     ☋         NaN
# 20    2023      69     ☋         NaN
# 28    2023      96     ☋         NaN
# 35    2023     122     ☋         NaN
# ...    ...     ...   ...         ...
# 2058  2023     229     ☋         NaN
# 2066  2023     255     ☋         NaN
# 2073  2023     282     ☋         NaN
# 2081  2023     309     ☋         NaN
# 2089  2023     336     ☋         NaN
#
# [268 rows x 4 columns]

# %%
ascendingsshorts
# Out:
#      Year  Degree Event  Unnamed: 3
# 0    2023       1     ☊         NaN
# 8    2023      28     ☊         NaN
# 16   2023      54     ☊         NaN
# 24   2023      82     ☊         NaN
# 32   2023     108     ☊         NaN
# 39   2023     135     ☊         NaN
# 47   2023     163     ☊         NaN
# 55   2023     189     ☊         NaN
# 63   2023     216     ☊         NaN
# 71   2023     242     ☊         NaN
# 79   2023     269     ☊         NaN
# 86   2023     297     ☊         NaN
# 94   2023     323     ☊         NaN
# 102  2023     350     ☊         NaN

# %%
descendings.loc[descendings["Year"] < 2024]
# Out:
#       Year  Degree Event  Unnamed: 3
# 4     2023      16     ☋         NaN
# 12    2023      42     ☋         NaN
# 20    2023      69     ☋         NaN
# 28    2023      96     ☋         NaN
# 35    2023     122     ☋         NaN
# ...    ...     ...   ...         ...
# 2058  2023     229     ☋         NaN
# 2066  2023     255     ☋         NaN
# 2073  2023     282     ☋         NaN
# 2081  2023     309     ☋         NaN
# 2089  2023     336     ☋         NaN
#
# [268 rows x 4 columns]

# %%
ascendings.loc[ascendings["Year"] < 2024]
# Out:
#      Year  Degree Event  Unnamed: 3
# 0    2023       1     ☊         NaN
# 8    2023      28     ☊         NaN
# 16   2023      54     ☊         NaN
# 24   2023      82     ☊         NaN
# 32   2023     108     ☊         NaN
# 39   2023     135     ☊         NaN
# 47   2023     163     ☊         NaN
# 55   2023     189     ☊         NaN
# 63   2023     216     ☊         NaN
# 71   2023     242     ☊         NaN
# 79   2023     269     ☊         NaN
# 86   2023     297     ☊         NaN
# 94   2023     323     ☊         NaN
# 102  2023     350     ☊         NaN

# %%
descendings.plot()
# Out:
# <AxesSubplot:>

# %%
ascendings.plot()
# Out:
# <AxesSubplot:>

# %%
ascendings.Degree.astype(int) - descendings.Degree.astype(int)
# Out:
# 0      NaN
# 4      NaN
# 8      NaN
# 12     NaN
# 16     NaN
#         ..
# 2077   NaN
# 2081   NaN
# 2085   NaN
# 2089   NaN
# 2093   NaN
# Name: Degree, Length: 537, dtype: float64

# %%
ascdesc = pd.DataFrame(ascendings.Degree.astype(int), descendings.Degree.astype(int))

# %%
ascdesc
# Out:
#         Degree
# Degree
# 16        54.0
# 42         NaN
# 69         NaN
# 96         NaN
# 122        NaN
# ...        ...
# 229        NaN
# 255        NaN
# 282      246.0
# 309        NaN
# 336       75.0
#
# [268 rows x 1 columns]
